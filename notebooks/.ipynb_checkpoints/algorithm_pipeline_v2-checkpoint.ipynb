# %% [markdown]
# # matrix factorization on artists (or albums) and supporters

# %% [markdown]
# ## 1. read in albums_supporters table
# ## 2. construct similarity matrix (sparse I think!)
# ## 3. try matrix similarity to return similar artists or albums

# %%
import os
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
from scipy.sparse import coo_matrix
import scipy
import psycopg2
import tqdm
import numpy as np

# %% [markdown]
# ## connect to database

# %%
#In Python: Define a database name (we're using a dataset on births, so I call it 
# birth_db), and your username for your computer (CHANGE IT BELOW). 
dbname = 'music_db'
username = 'shayneufeld'

# connect:
con = None
con = psycopg2.connect(database = dbname, user = username)

# %% [markdown]
# ## read in album_supporters table

# %%
# query:
sql_query = """
SELECT * FROM album_supporters;
"""
album_supporters = pd.read_sql_query(sql_query,con)

# %% [markdown]
# ## read in album_info tabl

# %%
# query:
sql_query = """
SELECT * FROM album_info;
"""
album_info = pd.read_sql_query(sql_query,con)

# %% [markdown]
# ### if artist table is already created, load it here. Otherwise, start making it below:

# %%
artist_table = pd.read_csv('/Users/shayneufeld/Dropbox/insight/pricecamp/data/artist_table.csv')

# %% [markdown]
# ## summary of supporters table

# %%
num_artists = album_supporters.artist_name.unique().shape[0]
num_albums = album_supporters.album_url.unique().shape[0]
num_supporters = album_supporters.contrib_url.unique().shape[0]
num_sales = album_supporters.shape[0]

print('Number of artists: %.0f' % num_artists)
print('Number of albums: %.0f' % num_albums)
print('Number of supporters: %.0f' % num_supporters)
print('Number of sales: %.0f' % num_sales)
# Out:
# Number of artists: 1657
# Number of albums: 5279
# Number of supporters: 242214
# Number of sales: 1978296

# %% [markdown]
# # create sparse matrix
#
# from: http://www.benfrederickson.com/matrix-factorization/
# ```
# # read in triples of user/artist/playcount from the input dataset
# data = pandas.read_table("usersha1-artmbid-artname-plays.tsv",
#                          usecols=[0, 2, 3],
#                          names=['user', 'artist', 'plays'])
#
# # map each artist and user to a unique numeric value
# data['user'] = data['user'].astype("category")
# data['artist'] = data['artist'].astype("category")
#
# # create a sparse matrix of all the artist/user/play triples
# plays = coo_matrix((data['plays'].astype(float),
#                    (data['artist'].cat.codes,
#                     data['user'].cat.codes)))
# ```

# %%
artist_matrix = album_supporters[['artist_name', 'contrib_url']].copy()

# %%
artist_matrix['artist_name'] = artist_matrix['artist_name'].astype('category')
artist_matrix['contrib_url'] = artist_matrix['contrib_url'].astype('category')
artist_matrix['buys'] = 1

# %%
buys = coo_matrix((artist_matrix['buys'].astype(float),
                  (artist_matrix['artist_name'].cat.codes,
                  artist_matrix['contrib_url'].cat.codes)))

# %%
# try saving matrix
scipy.sparse.save_npz('/Users/shayneufeld/Dropbox/insight/pricecamp/data/supporters_sparse_matrix.npz', buys)
sparse_matrix = scipy.sparse.load_npz('/Users/shayneufeld/Dropbox/insight/pricecamp/data/supporters_sparse_matrix.npz')

# %%
type(sparse_matrix)
# Out:
# scipy.sparse.coo.coo_matrix

# %%
artist_key = dict(enumerate(artist_matrix.artist_name.cat.categories))

# %%
len(artist_key)
# Out:
# 1657

# %% [markdown]
# # create an artist_table

# %%
# create a table for each artist, containing number of albums & tags
artist_table = pd.DataFrame()

for i,key in tqdm.tqdm(enumerate(artist_key)):
    artist = artist_key[key]
    artist_info = album_info[album_info.artist_name == artist]
    artist_supp = album_supporters[album_supporters.artist_name == artist]
    
    total_supp = artist_supp.shape[0]
    unique_supp = artist_supp.contrib_url.unique().shape[0]
    num_albums = artist_supp.album_name.unique().shape[0]
    
    artist_tags = str()
    for album_tags in artist_info.tags.values:
        artist_tags = artist_tags + str(album_tags[1:-1])
    
    d = {'name':artist,'tags':artist_tags,
         'num_albums':num_albums,'num_buys':total_supp,
        'num_buyers':unique_supp,'artist_id':key}
    
    artist_table = artist_table.append(pd.DataFrame(data=d,index=[i]))
# Out:
# 1657it [06:48,  3.89it/s]

# %% [markdown]
# ## add number of sales to artist_table

# %%
for i in tqdm.tqdm(np.arange(artist_table.shape[0])):
    name = artist_table.iloc[i]['name']
    
    artist_sales = sales[sales.artist_name==name]
    num_sales = artist_sales.shape[0]
    
    artist_table.loc[i,'num_recorded_sales'] = num_sales
# Out:
# 100%|██████████| 1657/1657 [00:24<00:00, 67.44it/s]

# %%
artist_table.head(5)
# Out:
#    artist_id                 name  num_albums  num_buyers  num_buys  \
# 0          0       (Sandy) Alex G           4        2323      3441
# 1          1       ,,abrightfar,,           1           3         6
# 2          2  ...Of Sinking Ships           1          25        50
# 3          3     1800HaightStreet           1         166       166
# 4          4    1970's Film Stock           1           5        10
#
#                                                 tags
# 0  'alex g', 'pop', 'domino''nsfw', 'pop''pop', '...
# 1  'experimental', 'abrightfar', 'ambient', 'brok...
# 2  'atmospheric', 'hopesfall', 'indie', 'indie ro...
# 3  'chicago house', 'deep techno', 'detroit house...
# 4  '1970s', 'experimental', 'broken machine films...

# %%
def bm25_weight(X, K1=100, B=0.8):
    """ Weighs each row of a sparse matrix X  by BM25 weighting """
    # calculate idf per term (user)
    X = coo_matrix(X)

    N = float(X.shape[0])
    idf = np.log(N / (1 + np.bincount(X.col)))

    # calculate length_norm per document (artist)
    row_sums = np.ravel(X.sum(axis=1))
    average_length = row_sums.mean()
    length_norm = (1.0 - B) + B * row_sums / average_length

    # weight matrix rows by bm25
    X.data = X.data * (K1 + 1.0) / (K1 * length_norm[X.row] + X.data) * idf[X.col]
    return X

# %%
from scipy.sparse import linalg

# %%
artist_factors, _, user_factors = linalg.svds(bm25_weight(buys), 50)

# %%
class TopRelated(object):
    def __init__(self, artist_factors):
        # fully normalize artist_factors, so can compare with only the dot product
        norms = np.linalg.norm(artist_factors, axis=-1)
        self.factors = artist_factors / norms[:, np.newaxis]

    def get_related(self, artistid, N=20):
        scores = self.factors.dot(self.factors[artistid])
        best = np.argpartition(scores, -N)[-N:]
        return sorted(zip(best, scores[best]), key=lambda x: -x[1])

# %%
top20 = TopRelated(artist_factors)
result = top20.get_related(678)
related_artists = []
for r in result:
    artist_name = artist_key[r[0]]
    tags = artist_table[artist_table.artist_name==artist_name].tags.values
    related_artists.append(artist_name)
    print('%s : %.02f : %s\n\n' %(artist_name,r[1],tags))
# Out:
# Joe Seven : 1.00 : [ "['autonomic', 'drum & bass', 'electronic', 'bass music', 'electronica', 'indie']"]
#
#
# Heart Drive : 0.99 : [ "['autonomic', 'drum & bass', 'electronic', 'heart drive', 'bass music', 'electronica', 'indie']"]
#
#
# The Binary Collective : 0.98 : [ "['autonomic', 'drum & bass', 'electronic', 'soundtrack music', 'bass music', 'electronica', 'electronica.', 'film score', 'indie']"]
#
#
# Instra:mental : 0.98 : [ "['autonomic', 'drum & bass', 'electronic', 'bass music', 'electronica', 'indie']"]
#
#
# Marcus Intalex : 0.98 : [ "['autonomic', 'drum & bass', 'electronic', 'bass music', 'electronica', 'indie']"]
#
#
# System : 0.98 : [ "['autonomic', 'drum & bass', 'electronic', 'bass music', 'electronica', 'indie']"]
#
#
# dBridge : 0.98 : [ "['autonomic', 'drum & bass', 'electronic', 'bass music', 'electronica', 'indie']"]
#
#
# Module Eight : 0.97 : [ "['autonomic', 'drum & bass', 'electronic', 'bass music', 'electronica', 'indie']"]
#
#
# ...

# %% [markdown]
# ## Given a set of similar artists, we want to:
#
# 1. look at the sales data for these artists at see what kind of merchandise / for what price they are buying
# 2. based on this ratio

# %%
sales = pd.read_csv('/Users/shayneufeld/Dropbox/insight/pricecamp/data/sales.csv',index_col=0)

# %%
artist_id = 50
result = top20.get_related(artist_id)
related_artists = []
for r in result:
    artist_name = artist_key[r[0]]
    tags = artist_table[artist_table.artist_name==artist_name].tags.values
    related_artists.append(artist_name)
    
print('Artist: %s' % artist_key[artist_id])
print('Related artists: %s' % related_artists)
# Out:
# Artist: Al Dobson Jr
# Related artists: ['Al Dobson Jr', 'Silentjay X Jace XL', 'Earth Trax X Newborn Jr.', 'Retiree', 'Duke Hugh', 'Junior', 'Prequel', 'Kaidi Tatham', 'dego & the 2000black family', 'FYI Chris', 'Tatham,Mensah,Lord & Ranks', 'Dan Kye', 'Lordamercy', 'Contours', 'dego', 'Chaos In The CBD', 'Henry Wu', 'Idris Rahman, Leon Brichard, Tom Skinner', 'Jazzuelle & Lars Behrenroth Feat. Tamara Dey', 'Idris Rahman, Leon Brichard, Emre Ramazanoglu, Yahael Camara-Onono']

# %%
related_sales = pd.DataFrame()
for artist in related_artists:
    related_sales_ = sales[sales.artist_name==artist].copy()
    print('%s: %.0f' % (artist,related_sales_.shape[0]))
    related_sales = related_sales.append(related_sales_)
# Out:
# Al Dobson Jr: 0
# Silentjay X Jace XL: 1
# Earth Trax X Newborn Jr.: 0
# Retiree: 2
# Duke Hugh: 2
# Junior: 1
# Prequel: 2
# Kaidi Tatham: 7
# dego & the 2000black family: 14
# FYI Chris: 6
# Tatham,Mensah,Lord & Ranks: 31
# Dan Kye: 2
# Lordamercy: 0
# Contours: 0
# dego: 1
# Chaos In The CBD: 40
# Henry Wu: 14
# Idris Rahman, Leon Brichard, Tom Skinner: 29
# Jazzuelle & Lars Behrenroth Feat. Tamara Dey: 0
# Idris Rahman, Leon Brichard, Emre Ramazanoglu, Yahael Camara-Onono: 40

# %%
related_sales.shape[0]
# Out:
# 3

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.barplot(x='item_type',y='amount_paid_usd',data=related_sales)

# %%
item_types = related_sales.item_type.unique()
num_sales,rev = np.zeros(len(item_types)),np.zeros(len(item_types))

for i,item_type in enumerate(item_types):
    num_sales[i] = related_sales[related_sales.item_type==item_type].shape[0]
    rev[i] = related_sales[related_sales.item_type==item_type].amount_paid_usd.sum()
    print('%s sales: %.0f revenue: $%.0f' % (item_type,num_sales[i],rev[i]))
# Out:
# t sales: 27 revenue: $34
# a sales: 122 revenue: $528
# p sales: 43 revenue: $662

# %%
plt.figure(figsize=(12,5))
fontsize=20
for i,item_type in enumerate(item_types):
    test=related_sales[related_sales.item_type==item_type]
    x = np.histogram(test.amount_paid_usd.values)[1][:-1]
    y = np.histogram(test.amount_paid_usd.values)[0]*x
    plt.plot(x,y,label=item_type,linewidth=5)
plt.legend(loc='best',fontsize=fontsize)
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
plt.xlabel('item price ($)',fontsize=fontsize)
plt.ylabel('revenue ($)', fontsize=fontsize)

# %%
artist_name
# Out:
# ',,abrightfar,,'

# %%
# how many artists can I actually do this for right now?

num_sales = []
for key in tqdm.tqdm(artist_key):
    curr = artist
    artist_table.loc[artist_table.artist_name==artist_name,'num_sales_by_related_artists'] = n
    artist_table.loc[artist_table.artist_name==artist_name,'artist_id'] = key
    num_sales.append(n)
# Out:
# 100%|██████████| 1657/1657 [10:58<00:00,  3.00it/s]

# %%
print('Number of artists with over 400 sales of related artists: %.0f' % (np.sum(np.asarray(num_sales) > 400)))
# Out:
# Number of artists with over 400 sales of related artists: 311

# %%
artist_table.artist_id.max()
# Out:
# 1656.0

# %%
artist_table.shape
# Out:
# (1722, 6)

# %%
artist_table.sort_values('num_sales_by_related_artists',ascending=False)
# Out:
#                                   artist_name  num_albums  \
# 0                    悲しい ANDROID - APARTMENT¶           1
# 0                            Minimal Violence           1
# 0                                   Sasquatch           6
# 0                                     Tall T.           1
# 0                Djuma Soundsystem & Westerby           1
# 0                               Disasterpeace          10
# 0                             Various Artists          46
# 0   Hammock, Steve Kilbey & timEbandit Powles           1
# 0                                  NeonTropix           1
# 0                                        HOME           2
# 0                                   Lazerhawk           5
# 0                                 Herr Doktor           1
# 0                                        ALEX           2
# 0                                       FM-84           2
# 0                         DANCE WITH THE DEAD           7
# ...

# %%
artist_table.to_csv('/Users/shayneufeld/Dropbox/insight/pricecamp/data/artist_table.csv')

# %% [markdown]
# ## Implicit Alternating Least Squares
#
# haven't gotten this to work yet (can't figure out what the 'factors' in put in alternating least squares is supposed to be. Contacted the author of the post. For now, I'll settle with LSA and move on.

# %%
import implicit

# initialize a model
model = implicit.als.AlternatingLeastSquares(factors=50)

# %%
from timeit import default_timer as timer

# %%
# train the model on a sparse matrix of item/user/confidence weights
start = timer()
model.fit(buys)
end = timer()
print('Time to fit model: %.0f s' % (end-start))
# Out:
# Time to fit model: 21

# %%
# find related items
related = model.similar_items(1000,N=50)

# %% [markdown]
# # Compare LSA with implicit ALS

# %% [markdown]
# Let's add 'number of buys' (it total number of supporters) and 'number of buyers' (ie total number of unique supporters) to the `artist_table` for sake of comparing related artists computed by LSA and iALS

# %%
als = model #for clarity
lsa = TopRelated(artist_factors)

# %%
artist_id = 999
lsa_result = lsa.get_related(artist_id,N=50)
als_result = als.similar_items(artist_id,N=50)

results = zip(lsa_result,als_result)
lsa_,als_ = pd.DataFrame(),pd.DataFrame()

for lsa_r,als_r in results:
    #print(artist_table[artist_table.artist_id==lsa_r[0]])
    lsa_ = lsa_.append(artist_table[artist_table.artist_id==lsa_r[0]])
    als_ = als_.append(artist_table[artist_table.artist_id==als_r[0]])
    
#print('Artist: %s' % artist_key[artist_id])
#print('Related artists: %s' % related_artists)

# %%
artist_table[artist_table.num_buys > 100].shape
# Out:
# (778, 7)

# %%
lsa_
# Out:
#       artist_id                                name  num_albums  num_buyers  \
# 999         999                          Otto Rollo           1           2
# 725         725                          Knxwledge.          74        2577
# 723         723                                Knx.           1          55
# 1577       1577                           knxwledge           1         143
# 724         724                           Knxwledge           3         173
# 837         837                          Matt Bloom           2          22
# 1313       1313                    TVPES x KNABLINZ           1          19
# 1018       1018                        Pacific Star           1          40
# 811         811                                MIKE           9         522
# 15           15                  77 Rise Recordings           3          28
# 1379       1379                     The Stuyvesants           6         101
# ...

# %%
np.sum(sales.artist_name == lsa_artist)
# Out:
# 0

# %%
sales[sales.artist_name == als_artist]
# Out:
#    addl_count album_title amount_over_fmt  amount_paid amount_paid_fmt  \
# 0         NaN         NaN             NaN          9.0              $9
# 0         NaN         NaN             NaN          9.0              $9
# 0         NaN         NaN             NaN          9.0              $9
# 0         NaN         NaN             NaN          9.0              $9
# 0         NaN         NaN             NaN          9.0              $9
# 0         NaN         NaN             NaN          9.0              $9
# 0         NaN         NaN             NaN          9.0              $9
# 0         NaN         NaN             NaN          9.0              $9
# 0         NaN         NaN             NaN          9.0              $9
# 0         NaN         NaN              $3         12.0             $12
# 0         NaN         NaN              $3         12.0             $12
# 0         NaN         NaN             NaN          9.0              $9
# ...

# %%
related_artists = zip(als_.name.values,lsa_.name.values)
related_sales_als = pd.DataFrame()
related_sales_lsa = pd.DataFrame()

for als_artist,lsa_artist in related_artists:
    related_sales_als_ = sales[sales.artist_name==als_artist].copy()
    related_sales_lsa_ = sales[sales.artist_name==lsa_artist].copy()

    related_sales_als = related_sales_als.append(related_sales_als_)
    related_sales_lsa = related_sales_lsa.append(related_sales_lsa_)

# %%
print('Num related sales (als): %.0f' % related_sales_als.shape[0])
print('Num related sales (lsa): %.0f' % related_sales_lsa.shape[0])
# Out:
# Num related sales (als): 34
# Num related sales (lsa): 1728

# %%
album_info.head(5)
# Out:
#    index   Bundle Vinyl    CD  Tape Digital Unclassified  \
# 0      0     None  None  None  None      $1         None
# 1      1        (  None  None  None    70.4         None
# 2      2  $60.30   None  None  None     $13         None
# 3      3     None  None  None  None      $1         None
# 4      4     None  None  None  None      $5         None
#
#                     album_name               artist_name    location  \
# 0  "Condos"-LiveatTheBellHouse     Welcome to Night Vale    New York
# 1      "Emerson"UnreleasedDemo               Wintergatan  Gothenburg
# 2               "ILLESTRUSSIA"  PLAYA x TIGHT EYEZ x MMP     Ukraine
# 3   "TheDebate"-LiveatRoulette     Welcome to Night Vale    New York
# 4       "TheInvestigators"Live     Welcome to Night Vale    New York
#
#                                                 tags    year
# 0                                       ['podcasts']  2014.0
# 1                                            ['pop']  2017.0
# ...

# %%
related_sales[related_sales.amount_paid_usd == 6]
# Out:
#    addl_count album_title amount_over_fmt  amount_paid amount_paid_fmt  \
# 0         NaN         NaN              $6          6.0              $6
# 0         NaN         NaN              $6          6.0              $6
# 0         NaN         NaN              $6          6.0              $6
# 0         NaN         NaN             NaN          6.0              $6
# 0         NaN         NaN             NaN          6.0              $6
# 0         NaN         NaN             NaN          6.0              $6
# 0         NaN         NaN             NaN          6.0              $6
# 0         NaN         NaN             NaN          6.0              $6
# 0         NaN         NaN             NaN          6.0              $6
# 0         NaN         NaN             NaN          6.0              $6
# 0         NaN         NaN             NaN          6.0              $6
# 0         NaN         NaN             NaN          6.0              $6
# ...

# %%
album_info[album_info.artist_name == 'Tchornobog']
# Out:
#       index Bundle Vinyl    CD  Tape Digital Unclassified  album_name  \
# 2530   2525   None  None  None  None    None         None  Tchornobog
#
#      artist_name       location  \
# 2530  Tchornobog  United States
#
#                                                    tags    year
# 2530  ['ambient', 'atmospheric', 'atmospheric black ...  2017.0

# %%
related_sales = related_sales_als
item_types = related_sales.item_type.unique()
plt.figure(figsize=(12,5))
fontsize=20
for i,item_type in enumerate(item_types):
    test=related_sales[related_sales.item_type==item_type]
    x = np.histogram(test.amount_paid_usd.values)[1][:-1]
    y = np.histogram(test.amount_paid_usd.values)[0]*x
    plt.plot(x,y,linewidth=5)
    plt.scatter(x,y,label=item_type,linewidth=5)
plt.legend(loc='best',fontsize=fontsize)
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
plt.xlabel('item price ($)',fontsize=fontsize)
plt.ylabel('revenue ($)', fontsize=fontsize)

# %%
d = {'a':1}
d['b'] = 2

# %%
d
# Out:
# {'a': 1, 'b': 2}

# %%
best_price['a']=4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-386-c19ae7625073> in <module>()
# ----> 1 best_price['a']=4
#
# TypeError: list indices must be integers or slices, not str

# %%
related_sales = related_sales_lsa
item_types = related_sales.item_type.unique()
plt.figure(figsize=(12,5))
fontsize=20
best_price = {}
for i,item_type in enumerate(item_types):
    temp=related_sales[related_sales.item_type==item_type]
    x = np.histogram(temp.amount_paid_usd.values)[1][:-1]
    y = np.histogram(temp.amount_paid_usd.values)[0]*x
    opt = x[np.where(y==y.max())]
    best_price[item_type] = np.round(opt[0])
    
    plt.scatter(x,y,label=item_type,linewidth=5)
    plt.plot(x,y,linewidth=5)
plt.legend(loc='best',fontsize=fontsize)
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
plt.xlabel('item price ($)',fontsize=fontsize)
plt.ylabel('revenue ($)', fontsize=fontsize)

# %%
artist_table
# Out:
#       artist_id                                               name  \
# 0             0                                     (Sandy) Alex G
# 1             1                                     ,,abrightfar,,
# 2             2                                ...Of Sinking Ships
# 3             3                                   1800HaightStreet
# 4             4                                  1970's Film Stock
# 5             5                                                 28
# 6             6                                               2814
# 7             7                                         3 Ninjasks
# 8             8                                       36 Questions
# 9             9                                               5ive
# 10           10                                             6Blocc
# 11           11                                      6Blocc and J5
# 12           12                            6Blocc and Junior Demus
# ...

# %%
best_price
# Out:
# {'a': 8.0, 'b': 10.0, 'p': 19.0, 't': 1.0}

# %% [markdown]
# okay now I need to figure out how to recommend it. Should not recommend all products every time. here, doesn't make sense to recommend tracks right?

# %%
y.max()
# Out:
# 264.60000000000002

# %%
np.where(y == y.max())
# Out:
# (array([0]),)

# %%
related_albums = pd.DataFrame()
for name in als_.name.values:
    related_albums = related_albums.append(album_info[album_info.artist_name==name])
    num_supporters = album_supporters[album_supporters]

# %%
related_albums
# Out:
#       index    Bundle  Vinyl    CD   Tape Digital Unclassified  \
# 3544    417     $993    None  None     $7      $5         None
# 5113   1990      None    $16  None   None     $10         None
# 3375    249  $297.41    None  None   None   $6.16         None
# 4102    979      None   None  None   None    None         None
# 4056    933  $297.41    None  None   None   $8.18         None
# 4537   1414      None   None  None   None      $7         None
# 5476   2353      None   None  None   None      $7         None
# 4959   1836      None   None  None   None      £3         None
# 5331   2208      None   None  None   None      £5         None
# 3732    609      None   None  None   None      $5         None
# 5322   2199  $297.41    None  None   None      $2         None
# 5440   2317      None   None  None   None    None         None
# 3235    108  £113.87    None  None  £9.99      £8         None
# 4912   1789     $993    None  None     $7      $6         None
# ...

# %% [markdown]
# # distributions of different products

# %%
def get_price_hist(item_type,data):
    prices = []
    for item in tqdm.tqdm(album_info[item_type].values):
        if not item == None:
            if ((item[0] == '$') or (item[0] == '£') or (item[0] == '€')):
                price = float(item[1:])

            else:
                try:
                    price = (float(item))
                except:
                    price = None

            prices.append(price)
    
    prices = np.asarray(prices)
    prices = prices[prices != None]
    return prices

# %%
prices_digital = get_price_hist('Digital',album_info)
prices_CD = get_price_hist('CD',album_info)
prices_tape = get_price_hist('Tape',album_info)
prices_vinyl = get_price_hist('Vinyl',album_info)
prices_bundle = get_price_hist('Bundle',album_info)
# Out:
# ...
# 100%|██████████| 5477/5477 [00:00<00:00, 730273.17it/s]

# %%
prices_digital.shape
# Out:
# (4610,)

# %%
prices_tape.shape
# Out:
# (243,)

# %%
prices = [prices_digital,prices_CD,prices_tape,prices_vinyl,prices_bundle]
price_type = ['Digital','CD','Tape','Vinyl','Bundle']

for price,price_type in zip(prices,price_type):
    plt.hist(prices,bins=int(price.shape[0]/10),normed=True,label=price_type)
    #plt.title(price_type)
    plt.xlim(0,40)

plt.legend(loc='best')

# %% [markdown]
# too messy. I imagine it would become clearer if i clustered it by music genre

# %%
album_supporters.head(5)
# Out:
#    index            artist_name                 contrib_name  \
# 0      0  Welcome to Night Vale                  ['Tashina']
# 1      1  Welcome to Night Vale                 ['Gabriela']
# 2      2  Welcome to Night Vale  ["Schrödinger's Time Lady"]
# 3      3  Welcome to Night Vale            ['katoofchitown']
# 4      4  Welcome to Night Vale               ['melodyrose']
#
#                                          contrib_url  \
# 0  https://bandcamp.com/tashinakalmbach?from=fant...
# 1       https://bandcamp.com/melanoma?from=fanthanks
# 2     https://bandcamp.com/timeladies?from=fanthanks
# 3  https://bandcamp.com/katoofchitown?from=fanthanks
# 4     https://bandcamp.com/melodyrose?from=fanthanks
#
#                     album_name  \
# 0  "Condos"-LiveatTheBellHouse
# 1  "Condos"-LiveatTheBellHouse
# 2  "Condos"-LiveatTheBellHouse
# 3  "Condos"-LiveatTheBellHouse
# 4  "Condos"-LiveatTheBellHouse
#
#                                            album_url
# ...
